# %%
import pandas as pd
import datetime

# %%
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# import pandas as pd

# # Define your scope
# scope = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive']


# # Add your credentials file
# credentials = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize your credentials
# client = gspread.authorize(credentials)
# # List all available spreadsheets
# spreadsheet_list = client.openall()

# print("The following Google Sheets documents are available:")
# for spreadsheet in spreadsheet_list:
#     print(spreadsheet.title)

# %%
# pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2 gspread

# %%
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials

# # Define the scope
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# # Add your service account file
# creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize the clientsheet 
# client = gspread.authorize(creds)

# # Get the instance of the Spreadsheet
# sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

# # Get the first sheet of the Spreadsheet
# sheet = sheet_instance.get_worksheet_by_id("1596581017")

# # Get all records of the data and print it out as list
# # df = sheet.get_all_records()
# read_last_index=0
# write_last_index=0
# df = pd.DataFrame(sheet.get_all_records())
# print(df.columns)
# # Convert 'Conversation' column to string type
# df['Message'] = df['Message'].astype(str)

# # Group by 'Mobile' column and join 'Conversation' column
# df = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()
# # print(client)

# # print(client)
# df = df[~df['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]


# sheet = sheet_instance.get_worksheet_by_id("757590641")

# # Clear all existing data in the sheet
# sheet.clear()

# # Convert DataFrame to list of lists for gspread
# data = [df.columns.to_list()] + df.values.tolist()

# # Write data to sheet
# sheet.insert_rows(data, row=1)

# %%
# import pandas as pd
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials

# # Define the scope
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# # Add your service account file
# creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize the clientsheet 
# client = gspread.authorize(creds)

# # Get the instance of the Spreadsheet
# sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

# # Get the first sheet of the Spreadsheet
# sheet = sheet_instance.get_worksheet_by_id("1596581017")

# # Get all records of the data and print it out as list
# df = pd.DataFrame(sheet.get_all_records())

# # Convert 'Conversation' column to string type
# df['Message'] = df['Message'].astype(str)

# # Group by 'Mobile' column and join 'Conversation' column
# df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

# # Filter out unwanted messages
# df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

# # Add a new column with minimum timestamp for each phone number
# df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

# # Merge DataFrames on 'User Mobile Number'
# df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

# # Sort by timestamp in ascending order
# df_final.sort_values(by='Timestamp', inplace=True)

# sheet = sheet_instance.get_worksheet_by_id("757590641")

# # Clear all existing data in the sheet
# sheet.clear()

# # Convert DataFrame to list of lists for gspread
# data = [df_final.columns.to_list()] + df_final.values.tolist()

# # Write data to sheet
# sheet.insert_rows(data, row=1)

# %%
# import pandas as pd
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# import schedule
# import time

# # Define the scope
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# # Add your service account file
# creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize the clientsheet 
# client = gspread.authorize(creds)

# # Get the instance of the Spreadsheet
# sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')
# read_last_index=0
# write_last_index=0
# def process_data():
#     # Get the first sheet of the Spreadsheet
#     sheet = sheet_instance.get_worksheet_by_id("1596581017")
#     start_reading_index=read_last_index
#     # Get all records of the data and print it out as list
#     df = pd.DataFrame(sheet.get_all_records())
#     read_last_index=df.lastindex()
#     # Convert 'Conversation' column to string type
#     df['Message'] = df['Message'].astype(str)

#     # Group by 'Mobile' column and join 'Conversation' column
#     df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

#     # Filter out unwanted messages
#     df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

#     # Add a new column with minimum timestamp for each phone number
#     df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

#     # Merge DataFrames on 'User Mobile Number'
#     df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

#     # Sort by timestamp in ascending order
#     df_final.sort_values(by='Timestamp', inplace=True)

#     sheet_output = sheet_instance.get_worksheet_by_id("757590641")

#     startWriting_index=write_last_index+1

#     # Convert DataFrame to list of lists for gspread
#     data = [df_final.columns.to_list()] + df_final.values.tolist()
#     write_last_index=len(data)
#     # Write data to output sheet starting from where it left off (if stored)
    
# schedule.every(120).minutes.do(process_data)

# while True:
# 	schedule.run_pending()
# 	time.sleep(1)

# %%
# import pandas as pd
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# import schedule
# import time

# # Define the scope
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# # Add your service account file
# creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize the clientsheet 
# client = gspread.authorize(creds)

# # Get the instance of the Spreadsheet
# sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')
# read_last_index=0
# write_last_index=0

# def get_last_processed_index():
#     try:
#         with open("last_processed_index.txt", "r") as file:
#             return int(file.read())
#     except FileNotFoundError:
#         return 0

# def update_last_processed_index(index):
#     with open("last_processed_index.txt", "w") as file:
#         file.write(str(index))

# def process_data():
#     global read_last_index, write_last_index
    
#     # Get the first sheet of the Spreadsheet
#     sheet = sheet_instance.get_worksheet_by_id("1596581017")
    
#     start_reading_index = get_last_processed_index()

# # Get all records of the data and print it out as a list
#     df = pd.DataFrame(sheet.get_all_records())[start_reading_index:]
    
#     # Convert 'Conversation' column to string type
#     df['Message'] = df['Message'].astype(str)

#     # Group by 'Mobile' column and join 'Conversation' column
#     df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

#     # Filter out unwanted messages
#     df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

#     # Add a new column with minimum timestamp for each phone number
#     df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

#     # Merge DataFrames on 'User Mobile Number'
#     df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

#     # Sort by timestamp in ascending order
#     df_final.sort_values(by='Timestamp', inplace=True)
    
#     new_data_length = len(df_final) - start_reading_index
    
#     if new_data_length > 0:
#         sheet_output = sheet_instance.get_worksheet_by_id("757590641")
        
#         start_writing_index = write_last_index + 1
        
#         # Convert DataFrame to list of lists for gspread (only new data)
#         data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()[start_reading_index:]
        
#         write_last_index += len(data_to_write) - 1
        
#         # Write data to output sheet starting from where it left off (if stored)
#         sheet_output.append_rows(data_to_write)
        
#         update_last_processed_index(len(df_final)+start_reading_index)
    
#     print(datetime.datetime.now())
# process_data()
# # schedule.every(120).minutes.do(process_data)

# # while True:
# # 	schedule.run_pending()
# # 	time.sleep(1)

# %%
# len(df)

# %%
# def process_data():
#     global write_last_index_Summary_sheet

#     # Get the first sheet of the Spreadsheet
#     sheet = sheet_instance.get_worksheet_by_id("1596581017")
    
#     start_reading_index = get_last_processed_index() + 1

#     # Get all records of the data starting from last processed index
#     df = pd.DataFrame(sheet.get_all_records())[start_reading_index:]
    
#     if len(df) > 0:  # Check if there's new data
#         # Convert 'Message' column to string type
#         df['Message'] = df['Message'].astype(str)
#         # Group by 'User Mobile Number' column and join 'Message' column
#         df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()
        
#         # Filter out unwanted messages
#         df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]
        
#         # Add a new column with minimum timestamp for each phone number
#         df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()
        
#         # Merge DataFrames on 'User Mobile Number'
#         df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')
        
#         # Sort by timestamp in ascending order
#         df_final.sort_values(by='Timestamp', inplace=True)
        
#         sheet_output = sheet_instance.get_worksheet_by_id("757590641")
        
#         start_writing_index = write_last_index_Summary_sheet + 1
        
#         # Convert DataFrame to list of lists for gspread (only new data)
#         data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()
        
#         write_last_index_Summary_sheet += len(data_to_write) - 1
        
#         # Write data to output sheet starting from where it left off (if stored)
#         sheet_output.append_rows(data_to_write, table_range=f"A{start_writing_index}")
        
#         # Update last processed index after processing new data
#         update_last_processed_index(start_reading_index + len(df) - 1)

#     print(datetime.datetime.now())
# process_data()

# %%
# !pip install gspread oauth2client pandas

# %%
# import pandas as pd
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# import schedule
# import time

# # Define the scope
# scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# # Add your service account file
# creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# # Authorize the clientsheet 
# client = gspread.authorize(creds)

# # Get the instance of the Spreadsheet
# sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

# def get_last_processed_index():
#     try:
#         with open('index_file.txt', 'r') as file:
#             for line in file:
#                 if line.startswith('read_last_index='):
#                     read_last_index = int(line.split('=')[1].strip())
#                 elif line.startswith('write_last_index='):
#                     write_last_index = int(line.split('=')[1].strip())
#             return read_last_index, write_last_index
#     except FileNotFoundError:
#         return 0, 0 # Return default values if file doesn't exist or is empty

# def update_last_processed_index(read_index, write_index):
#     with open('index_file.txt', 'w') as file:
#         file.write(f'read_last_index={read_index}\n')
#         file.write(f'write_last_index={write_index}\n')

# def process_data():
#     # Get the first sheet of the Spreadsheet
#     sheet = sheet_instance.get_worksheet_by_id("1596581017")

#     read_last_index, write_last_index = get_last_processed_index()
#     print(read_last_index)
#     df = pd.DataFrame(sheet.get_all_records())[read_last_index:]

#     # Convert 'Conversation' column to string type
#     df['Message'] = df['Message'].astype(str)

#     # Group by 'Mobile' column and join 'Conversation' column
#     df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

#     # Filter out unwanted messages
#     df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

#     # Add a new column with minimum timestamp for each phone number
#     df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

#     # Merge DataFrames on 'User Mobile Number'
#     df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

#     # Sort by timestamp in ascending order
#     df_final.sort_values(by='Timestamp', inplace=True)
#     df_final['Timestamp'] = pd.to_datetime(df_final['Timestamp'], format='%d/%m/%Y')

#     new_data_length = len(df_final) - write_last_index
#     print(new_data_length)
#     if new_data_length > 0:
#         sheet_output = sheet_instance.get_worksheet_by_id("757590641")

#         # Convert DataFrame to list of lists for gspread (only new data)
#         data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()[read_last_index:]

#         # Write data to output sheet starting from where it left off (if stored)
#         sheet_output.append_rows(data_to_write)
#         print(len(df)+read_last_index, write_last_index + new_data_length)
#         update_last_processed_index(len(df)+read_last_index+1, write_last_index + new_data_length)

# process_data()
# # schedule.every(120).minutes.do(process_data)

# # while True:
# # 	schedule.run_pending()
# # 	time.sleep(1)

# %%
def process_timestamp(df):
    for index, row in df.iterrows():
        try:
            # Convert 'Timestamp' column to datetime format
            timestamp = pd.to_datetime(row['Timestamp'], format='%d/%m/%Y', errors='coerce')

            # Check if conversion resulted in NaT (Not a Time)
            if pd.isna(timestamp):
                raise ValueError(f"Invalid timestamp format: {row['Timestamp']}")

            # Update 'Timestamp' in the DataFrame
            df.at[index, 'Timestamp'] = timestamp
            
        except Exception as e:
            print(f"Error processing timestamp at index {index}: {e}")
            # Drop row if there was an error processing
            df.drop(index, inplace=True)
    
    # Sort DataFrame by Timestamp (ignoring NaT)
    df.sort_values(by='Timestamp', inplace=True, na_position='last')
    
    # Remove NaT rows
    df.dropna(subset=['Timestamp'], inplace=True)
    return df

# %%
# 28/06/2024	917980860381	assistant	Sir, I can help you over a phone call. Please call Sulekha ma'am at 8800025223 at your convenience.
# 01/07/2024	919721404800	user	hi, I have a Product complaint.

def process_timestamp(df):
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%d/%m/%Y', errors='coerce')
    df.dropna(subset=['Timestamp'], inplace=True)
    df['Timestamp'] = df['Timestamp'].dt.strftime('%d-%m-%Y')  # Convert Timestamp to string in dd-mm-yyyy HH:MM:SS format
    df.sort_values(by='Timestamp', inplace=True, na_position='last')
    return df

import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import schedule
import time

# Define the scope
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# Add your service account file
creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# Authorize the clientsheet 
client = gspread.authorize(creds)

# Get the instance of the Spreadsheet
sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

def get_last_processed_index():
    try:
        with open('index_file.txt', 'r') as file:
            for line in file:
                if line.startswith('read_last_index='):
                    read_last_index = int(line.split('=')[1].strip())
                elif line.startswith('write_last_index='):
                    write_last_index = int(line.split('=')[1].strip())
            return read_last_index, write_last_index
    except FileNotFoundError:
        return 0, 0 # Return default values if file doesn't exist or is empty

def update_last_processed_index(read_index, write_index):
    with open('index_file.txt', 'w') as file:
        file.write(f'read_last_index={read_index}\n')
        file.write(f'write_last_index={write_index}\n')

def process_data():
    # Get the first sheet of the Spreadsheet
    sheet = sheet_instance.get_worksheet_by_id("1596581017")

    read_last_index, write_last_index = get_last_processed_index()
    print(read_last_index)
    df = pd.DataFrame(sheet.get_all_records())[read_last_index:]

    # Convert 'Conversation' column to string type
    df['Message'] = df['Message'].astype(str)

    # Group by 'Mobile' column and join 'Conversation' column
    df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

    # Filter out unwanted messages
    df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

    # Add a new column with minimum timestamp for each phone number
    df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

    # Merge DataFrames on 'User Mobile Number'
    df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

    # Sort by timestamp in ascending order

    df_final=process_timestamp(df_final)
    df_final.dropna(inplace=True,axis=1)
    print(df_final.head(7))


    ###############
    # new_data_length = -len(df_final) + write_last_index
    new_data_length = len(df_final) 
    print(len(df_final), write_last_index)
    print(new_data_length)
    if new_data_length > 0:
        sheet_output = sheet_instance.get_worksheet_by_id("415710006")

        # Convert DataFrame to list of lists for gspread (only new data)
        # data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()[write_last_index:]
        # print(data_to_write)

        # Write data to output sheet starting from where it left off (if stored)
        data_to_write = df_final.values.tolist()
        sheet_output.append_rows(data_to_write)
        print(len(df)+read_last_index, write_last_index + new_data_length)
        update_last_processed_index(len(df)+read_last_index+1, write_last_index + new_data_length)

process_data()
# schedule.every(120).minutes.do(process_data)

# while True:
# 	schedule.run_pending()
# 	time.sleep(1)
# Out:
# 0
#      User Mobile Number                                            Message  \
# 184        919717635623  hi, I have a Product complaint.\nMicro SD Card...
# 201        919780075232  hi, I have a Product complaint. Hello! I'm sor...
# 213        919847611847  hi Hello there!\n\nHow can I assist you today?...
# 253        919993599730  REQUIRE: - TN 2465 Tonner Cartridge FOR BROTHE...
# 63         918285228189  https://cdnydm.com/wh/w4ukD4gx13Amx1GSg27Rkg.m...
# 31         917569700243  hi, I have a Product complaint. Hello! I'm sor...
# 152        919440979186  hi, I have a Product complaint. Hello! I'm sor...
#
#       Timestamp
# 184  01-07-2024
# 201  01-07-2024
# 213  01-07-2024
# 253  01-07-2024
# 63   01-07-2024
# 31   01-07-2024
# 152  01-07-2024
# 255 0
# 255
# 2940 255

# %%
# 28/06/2024	917980860381	assistant	Sir, I can help you over a phone call. Please call Sulekha ma'am at 8800025223 at your convenience.
# 01/07/2024	919721404800	user	hi, I have a Product complaint.

def process_timestamp(df):
    df['Timestamp'] = df['Timestamp'].apply(lambda x: x.split("/"))
    df['Timestamp'] = df['Timestamp'].apply(lambda x: '-'.join([x[0], x[1], x[2]]))
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%d-%m-%Y', errors='coerce')
    df['Timestamp'] = df['Timestamp'].apply(lambda x: x.strftime('%d %B %Y')) # Dates will be displayed as "01 July 2024"
    df.sort_values(by='Timestamp', inplace=True)
    return df


import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import schedule
import time

# Define the scope
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# Add your service account file
creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# Authorize the clientsheet 
client = gspread.authorize(creds)

# Get the instance of the Spreadsheet
sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

def get_last_processed_index():
    try:
        with open('index_file.txt', 'r') as file:
            for line in file:
                if line.startswith('read_last_index='):
                    read_last_index = int(line.split('=')[1].strip())
                elif line.startswith('write_last_index='):
                    write_last_index = int(line.split('=')[1].strip())
            return read_last_index, write_last_index
    except FileNotFoundError:
        return 0, 0 # Return default values if file doesn't exist or is empty

def update_last_processed_index(read_index, write_index):
    with open('index_file.txt', 'w') as file:
        file.write(f'read_last_index={read_index}\n')
        file.write(f'write_last_index={write_index}\n')

def process_data():
    # Get the first sheet of the Spreadsheet
    sheet = sheet_instance.get_worksheet_by_id("1596581017")

    read_last_index, write_last_index = get_last_processed_index()
    print(read_last_index)
    df = pd.DataFrame(sheet.get_all_records())[read_last_index:]

    # Convert 'Conversation' column to string type
    df['Message'] = df['Message'].astype(str)

    # Group by 'Mobile' column and join 'Conversation' column
    df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

    # Filter out unwanted messages
    df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

    # Add a new column with minimum timestamp for each phone number
    df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

    # Merge DataFrames on 'User Mobile Number'
    df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

    # Sort by timestamp in ascending order

    df_final=process_timestamp(df_final)
    df_final.dropna(inplace=True,axis=1)
    print(df_final.head(7))


    ###############
    # new_data_length = -len(df_final) + write_last_index
    new_data_length = len(df_final) 
    print(len(df_final), write_last_index)
    print(new_data_length)
    if new_data_length > 0:
        sheet_output = sheet_instance.get_worksheet_by_id("415710006")

        # Convert DataFrame to list of lists for gspread (only new data)
        # data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()[write_last_index:]
        # print(data_to_write)

        # Write data to output sheet starting from where it left off (if stored)
        data_to_write = df_final.values.tolist()
        sheet_output.append_rows(data_to_write)
        print(len(df)+read_last_index, write_last_index + new_data_length)
        update_last_processed_index(len(df)+read_last_index+1, write_last_index + new_data_length)

process_data()
# schedule.every(120).minutes.do(process_data)

# while True:
# 	schedule.run_pending()
# 	time.sleep(1)
# Out:
# 0
#      User Mobile Number                                            Message  \
# 124        919125310424  hi, I have a Product complaint. Hello! I'm sor...
# 96         918863810149  hi, I have a Product complaint. Hello there! I...
# 32         917569700243  hi, I have a Product complaint. Hello! I'm sor...
# 199        919751184747  good morning Good morning! How can I assist yo...
# 217        919847611847  hi Hello there!\n\nHow can I assist you today?...
# 246        919953551022  hi, I have a Product complaint. Hello! I'm sor...
# 107        918943424987  hi, I have a Product complaint. Hello there!\n...
#
#         Timestamp
# 124  01 July 2024
# 96   01 July 2024
# 32   01 July 2024
# 199  01 July 2024
# 217  01 July 2024
# 246  01 July 2024
# 107  01 July 2024
# 259 0
# 259
# 2982 259

# %%
# 28/06/2024	917980860381	assistant	Sir, I can help you over a phone call. Please call Sulekha ma'am at 8800025223 at your convenience.
# 01/07/2024	919721404800	user	hi, I have a Product complaint.

def process_timestamp(df):
    df['Timestamp'] = df['Timestamp'].apply(lambda x: x.split("/"))
    df['Timestamp'] = df['Timestamp'].apply(lambda x: '-'.join([x[2], x[1], x[0]])) # Changing order to 'Y-m-d' format for correct sorting
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%Y-%m-%d', errors='coerce')
    df.sort_values(by='Timestamp', inplace=True)
    df['Timestamp'] = df['Timestamp'].apply(lambda x: x.strftime('%d %B %Y'))
    return df


import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import schedule
import time

# Define the scope
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# Add your service account file
creds = ServiceAccountCredentials.from_json_keyfile_name('consistent-316505-d401bba34a78.json', scope)

# Authorize the clientsheet 
client = gspread.authorize(creds)

# Get the instance of the Spreadsheet
sheet_instance = client.open_by_key('1_Qv45ioF3Y6dR1IQJP-lpW_thI4Sg2LHh-tBx7iyi9E')

def get_last_processed_index():
    try:
        with open('index_file.txt', 'r') as file:
            for line in file:
                if line.startswith('read_last_index='):
                    read_last_index = int(line.split('=')[1].strip())
                elif line.startswith('write_last_index='):
                    write_last_index = int(line.split('=')[1].strip())
            return read_last_index, write_last_index
    except FileNotFoundError:
        return 0, 0 # Return default values if file doesn't exist or is empty

def update_last_processed_index(read_index, write_index):
    with open('index_file.txt', 'w') as file:
        file.write(f'read_last_index={read_index}\n')
        file.write(f'write_last_index={write_index}\n')

def process_data():
    # Get the first sheet of the Spreadsheet
    sheet = sheet_instance.get_worksheet_by_id("1596581017")

    read_last_index, write_last_index = get_last_processed_index()
    print(read_last_index)
    df = pd.DataFrame(sheet.get_all_records())[read_last_index:]

    # Convert 'Conversation' column to string type
    df['Message'] = df['Message'].astype(str)

    # Group by 'Mobile' column and join 'Conversation' column
    df_grouped = df.groupby('User Mobile Number')['Message'].apply(' '.join).reset_index()

    # Filter out unwanted messages
    df_filtered = df_grouped[~df_grouped['Message'].str.startswith(("Thank you for contacti", "Welcome","🙏",'"wel',"*","Thank you for"))]

    # Add a new column with minimum timestamp for each phone number
    df_min_timestamp = df.groupby('User Mobile Number')['Timestamp'].min().reset_index()

    # Merge DataFrames on 'User Mobile Number'
    df_final = pd.merge(df_filtered, df_min_timestamp, on='User Mobile Number', how='left')

    # Sort by timestamp in ascending order

    df_final=process_timestamp(df_final)
    df_final.dropna(inplace=True,axis=1)
    print(df_final.head(7))


    ###############
    # new_data_length = -len(df_final) + write_last_index
    new_data_length = len(df_final) 
    print(len(df_final), write_last_index)
    print(new_data_length)
    if new_data_length > 0:
        sheet_output = sheet_instance.get_worksheet_by_id("415710006")

        # Convert DataFrame to list of lists for gspread (only new data)
        # data_to_write = [df_final.columns.to_list()] + df_final.values.tolist()[write_last_index:]
        # print(data_to_write)

        # Write data to output sheet starting from where it left off (if stored)
        data_to_write = df_final.values.tolist()
        sheet_output.append_rows(data_to_write)
        print(len(df)+read_last_index, write_last_index + new_data_length)
        update_last_processed_index(len(df)+read_last_index+1, write_last_index + new_data_length)

process_data()
# schedule.every(120).minutes.do(process_data)

# while True:
# 	schedule.run_pending()
# 	time.sleep(1)
# Out:
# 0
#      User Mobile Number                                            Message  \
# 134        919222888678  "Welcome to PARSHVA COMPUTERS! \n🖥️🔒 Currently...
# 33         917676954748  We are wholesale  dealers & e-commerce  suppli...
# 178        919644536739  128 gb  sata \n521 gb sata\n256gb sata Hello t...
# 35         917685837237  hi, I have a Product complaint. Hi there! I'm ...
# 24         917309037670  संदेश भेजने के लिए आप का धन्यावाद आप से जल्द स...
# 44         917978629452  Monitor24inch Got it, you're having an issue w...
# 79         918606519999  hi, I have a Product complaint. Hi there! I'm ...
#
#         Timestamp
# 134  24 June 2024
# 33   24 June 2024
# 178  24 June 2024
# 35   24 June 2024
# 24   24 June 2024
# 44   24 June 2024
# 79   24 June 2024
# 259 0
# 259
# 2992 259
